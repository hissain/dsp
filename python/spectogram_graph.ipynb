# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='whitegrid')

def plot_graph(input_array, title):
    plt.figure(figsize=(8, 4))
    plt.plot(input_array, label=title)
    plt.xlabel('Time')
    plt.ylabel('Amplitude')
    plt.title(title)
    plt.legend()
    plt.show()
    
freq = [0.080000, 0.080926, 0.083701, 0.088313, 0.094744, 0.102967, 0.112951, 0.124654, 0.138029, 0.153023, 0.169576, 0.187620, 0.207082, 0.227886, 0.249946, 0.273174, 0.297476, 0.322755, 0.348909, 0.375832, 0.403417, 0.431551, 0.460122, 0.489014, 0.518112, 0.547298, 0.576455, 0.605465, 0.634211, 0.662578, 0.690451, 0.717719, 0.744271, 0.770000, 0.794803, 0.818581, 0.841236, 0.862678, 0.882822, 0.901584, 0.918891, 0.934672, 0.948864, 0.961410, 0.972259, 0.981367, 0.988698, 0.994222, 0.997917, 0.999768, 0.999768, 0.997917, 0.994222, 0.988698, 0.981367, 0.972259, 0.961410, 0.948864, 0.934672, 0.918891, 0.901584, 0.882822, 0.862678, 0.841236, 0.818581, 0.794803, 0.770000, 0.744271, 0.717719, 0.690451, 0.662578, 0.634211, 0.605465, 0.576455, 0.547298, 0.518112, 0.489014, 0.460122, 0.431551, 0.403417, 0.375832, 0.348909, 0.322755, 0.297476, 0.273174, 0.249946, 0.227886, 0.207082, 0.187620, 0.169576, 0.153023, 0.138029, 0.124654, 0.112951, 0.102967, 0.094744, 0.088313, 0.083701, 0.080926, 0.080000]
plot_graph(freq, "Hamming Window of len " + str(len(freq)))

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load spectrogram data from CSV file
spectrogram_data = np.loadtxt('spectrogram_data.csv', delimiter=',', dtype=float)

# Plot spectrogram
plt.imshow(spectrogram_data, aspect='auto', origin='lower', cmap='viridis')
plt.colorbar(label='Magnitude')
plt.xlabel('Segment')
plt.ylabel('Frequency Bin')
plt.title('Spectrogram')
plt.show()
